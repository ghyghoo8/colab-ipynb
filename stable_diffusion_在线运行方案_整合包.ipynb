# %% [markdown]
# <a href="https://colab.research.google.com/github/ghyghoo8/colab-ipynb/blob/main/stable_diffusion_%E5%9C%A8%E7%BA%BF%E8%BF%90%E8%A1%8C%E6%96%B9%E6%A1%88_%E6%95%B4%E5%90%88%E5%8C%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 《《《《《《《《《《前言 与 致谢》》》》》》》》》》
#
# ---
#
# - 2022.11.14更新：本笔记施工中，仍然可以正常运作，但本人正在修改其中的代码，目标是通过代码实现笔记全自动化，来代替普通用户对文件的操作。
#
# # 前言：
# 各位好，你们可以叫我bcdw。
#
# 本colab笔记用于满足“希望能快速上手云端部署stable diffusion”的朋友们的需求
#
# （当然，我也是这些朋友们之一）
#
# 无论您是否拥有性能强悍的电脑，您都可以考虑学习并部署一下该笔记
#
# - 没有强悍电脑的朋友们，也可以通过这份笔记，限时地使用高配置版stable-diffusion；
# - 有强悍电脑的朋友们，也依然可以考虑白嫖谷歌算力，实现程序双开甚至多开，提升自己使用的效率
#
# ---
# ---
#
# ## 注：本笔记目标是：部署stable diffusion webUI版ai绘图（白色界面），它具有一定的使用门槛；
#
# #### 1）如果您想使用简单易操作的Novel ai naifu版本的UI（深蓝色界面），请使用这个笔记：
#
# - [友情链接（这不是我的笔记）](https://colab.research.google.com/drive/1_Ma71L6uGbtt6UQyA3FjqW2lcZ5Bjck-#scrollTo=uQBR9zXQGJrn)
#
# #### 2）如果您想通过DreamBooth训练大模型ckpt文件，请使用这个笔记：
#
# - [我的另一个笔记（摘抄并翻译了国外大佬的笔记）【目前正在整体修改中】](https://colab.research.google.com/drive/1ua1mSArHrp_aQ6XerOMhutsGMD8Q2lYQ?usp=sharing)
#
# - 【备注：[原作者colab笔记](https://colab.research.google.com/github/TheLastBen/fast-stable-diffusion/blob/main/fast-DreamBooth.ipynb)】
#
#
# #### 3）如果您想使用已有的pt文件来爬取p站相似图片，请使用这个笔记：
#
# - [我的另一个笔记（摘抄自dalao的github和笔记）【最新进展：还没开始写））】](https://colab.research.google.com/drive/1VUE0tHhjqu-9mnJFe3v57XIy45FdmCb3?usp=sharing)
#
# - 【备注：[dalao的colab笔记原文](https://github.com/7eu7d7/pixiv_AI_crawler)；[dalao的github仓库](https://colab.research.google.com/drive/1jwZehdQ4V5rR2M8n1wAJ7P8QHstMAjOl?usp=sharing)】
#
# ---
#
# 本笔记持续更新中......
#
# 有任何问题或者意见都可以反馈给我~
#
# （联系我？[b站私信我](https://space.bilibili.com/12171834)即可）
#
# ---
#
# # 》》》》》》》》》》运行前须知：《《《《《《《《《《
#
# ---
#
# ## 一.【谷歌在colab中为 每个谷歌账号 都准备了一定的gpu算力和运行时间，专注于提供云端跑深度学习的服务。若要使用该服务，请准备好：】
#
# - 1. 注册好的谷歌账号（若干个，取决于需求）（每个账号每天大概能用三到六小时gpu算力，取决于跑gpu运算的强度；而cpu和存储空间则没有使用时长的限制。）
#
# - 2. 需要多少个账号，就准备多少份账号注册的google drive（最好是google drive）
# （不过如果您有别的云存储，应该也能用，我不清楚，但可以肯定的是，如果要用别的云存储，需要自行修改云盘加载相关的代码）（多个云盘之间同步数据比较麻烦，但没有更好的办法，因为实测不能在某个账号的colab里加载别的账号的google drive。）
#
# - 3. 这份笔记（在打开这份笔记的链接之后，您可能无法保存对笔记的更改，这是因为您打开的是我共享的笔记文件，若要对此笔记进行内容上的更改，请先在云盘里保存一份此笔记的复制，以后再打开这份笔记的时候，您可以从云盘里的笔记文件开始，右键--打开方式--colab，即可运行您自己云盘里的笔记文件，此后，您对笔记做的所有更改都将保存在云盘里的那份笔记文件里。）
#
# - 4. 确保能够时常查看笔记页面，避免挂机（曾几何时，有一群小机灵鬼，白嫖谷歌服务器跑挖矿，给谷歌惹急眼了，现在的colab，一方面进一步限制了免费的算力提供，另一方面会在笔记运行时，间歇性的弹“您还在电脑前吗”验证框（并不是很频繁，通常会在笔记页面无任何操作的半个小时甚至更久以后），未及时验证的话，程序会被谷歌叫停，并强制限制gpu的使用，持续一天时间。但如果您能做到及时验证，您就可以持续享受谷歌提供的这多达10gb显存的gpu服务。另外，请不要试图安装保持唤醒的一些脚本，比如说装在油猴或者暴力猴上的一些greasy fork脚本，他们会被colab识别，并直接取消您colab的使用权【但通过申诉，过不了多久谷歌会给你恢复的，毕竟你不是真的在用它挖矿，对吧？】）
#
# ---
#
# ## 二.【本笔记依照个人使用习惯而改，因此，若想在不改代码的情况下顺利使用本笔记，请准备好：】
#
# ---
#
# - ### 1. 一些数据资料（保存在云存储内）（具体包括：模型文件，训练图片，本地配置文件等内容。）
#
# ####┏━》》》》》》》》》》对该项的一些备注：《《《《《《《《《《
#
# ┃┃对于该项，您可以按照如下步骤：
#
# ┃┃
#
# ---
#
# ┃┃（1）、对于复杂的目录和小文件，使用我提供的压缩包，下载后上传至云盘根目录：
#
# ┃┃[根目录打包链接在此:onedrive(不含大模型)](https://1drv.ms/u/s!AtPzstWV1beviH4GCVNNVC9uBENJ?e=9dJqlh)
#
# ┃┃（注意：上传的文件夹目录不能有误，应该和google drive分享内容一致且在云盘根目录
#
# ┃┃下，否则代码会出错。）（都是些很小的文件和文件夹，您自己手动命名也行，不过用我提
#
# ┃┃供的压缩包上传到Google drive会更方便一点。）
#
# ┃┃
#
# ---
#
# ┃┃（2）、对于大的模型文件(cpkt、pt等)，使用我提供的google drive分享（找到stableckpt文件夹，大文件基本都在那里）：
#
# ┃┃
#
# ┃┃（注意：该办法较为繁琐，您需要对每个单独的文件使用“复制”，
#
# ┃┃到自己云盘的根目录，然后重命名删去“（复制）”，最后拖入正确的文件夹内。
#
# ┃┃[模型文件链接在此](https://drive.google.com/drive/folders/1YNvbYbzgOXOw65YRf3ieO_vdDE97gmtL?usp=sharing)
#
# ┃┃
#
# ---
#
# ┃┃（3）、如果您有额外的需求，可以考虑修改代码，并自行决定内容（这需要一定的门槛，不过我已经在下边代码处写了
#
# ┃┃一些注释，希望能帮到你，你需要准备的基本上只是你想放的文件所在的目录，以及你想把它们放到什么地方去）
#
# ┃┃
#
# ┃┃（注意：本笔记会优先在云端更新，所以可能会遇
#
# ┃┃到云盘下载的文件目录与云端略有不同的情况，可能是本人忘记更新云盘资源了，如果因此
#
# ┃┃遇到运行报错，请及时联系我。）
#
# ---
#
# ┃┃我在此展示：一份完整的，供本笔记使用的 云盘目录 应有的样子，供各位对照和比较：
#
# ┃┃[链接在此](https://drive.google.com/drive/folders/12C2RtVxIShnbgQyZRRiUDvHuvAiU9KXj?usp=sharing)
#
# ┃┃（此文件夹应出现在：你的云盘根目录下）
#
# ---
#
# ####┗━》》》》》》》》》》备注到此就结束了。《《《《《《《《《《
#
# ---
#
# - ### 2. 操作stable diffusion webUI的一些知识（关于这方面，我会在下方准备一些参考链接视频，供各位观看。）（本人在这方面也仅仅只是摸索期，欢迎大家分享经验。）
#
# ---
# ---
#
# # 致谢：
# ### 本笔记及我的所有其他相关笔记改写与摘抄自：
#
# - https://colab.research.google.com/drive/1_Ma71L6uGbtt6UQyA3FjqW2lcZ5Bjck-#scrollTo=KZ88G-iWCTs7
#
# - https://colab.research.google.com/drive/1L9s-VG4OJ3vgcjFN_H_qhuyebSgwAiKV?usp=sharing#scrollTo=9n6dkOe_zPSt
#
# - https://colab.research.google.com/drive/13k72ModViWq4ftj1gSME5eSf7UDUDSU6
#
# - https://colab.research.google.com/drive/1yf3-bUhTcfxRmAphJHVQQAD2ArYO1CRZ
#
# - https://colab.research.google.com/drive/1AfAmwLMd_Vx33O9IwY2TmO9wKZ8ABRRa
#
# - https://colab.research.google.com/drive/1zuK0u8UW8IKMEvVNz7lU34Qph_gS14XD#scrollTo=R-xAdMA5wxXd
#
# - https://colab.research.google.com/github/TheLastBen/fast-stable-diffusion/blob/main/fast-DreamBooth.ipynb#scrollTo=O3KHGKqyeJp9
#
# ---
# ---
#
# ### 使用的文件与数据来自：
# - https://github.com/AUTOMATIC1111/stable-diffusion-webui
#
# - https://github.com/liggest/stable-diffusion-webui-localization
#
# - https://github.com/TheLastBen/fast-stable-diffusion
#
# （如有遗漏，请联系我补充~）
#
# ---
#
# ## 关于一些实用的参考网站和在线工具
#
# 见：最后一个单元格
#
# ---
#
# ## 感谢dalao们的制作！
#
# (　ˇωˇ )◕∀◕｡)^ω^)
#
# ---
#
# ## bcdw注：
#
# - 1. 多和网友交流交流，分享您的心得，如果您有意愿，请参与到为圈内群体做贡献的群体中去，您也会学到东西的。
#
# - 2. 如果觉得本笔记好用，请将该网页分享给你认识的需要它的朋友，顺便不要忘了支持下原作者~ (很惭愧，我只是做了些微小的缝合工作。)
#
# ---
#
# 【如果您觉得本文篇幅过长，阻碍了您的使用，可以这样操作：右键--删除单元格】
#
# ---
#
# 》》》》》》》》》》》》接下来就是代码运行环节《《《《《《《《《《《《
#
# 》》》》》》》》》》》》接下来就是代码运行环节《《《《《《《《《《《《
#
# 》》》》》》》》》》》》接下来就是代码运行环节《《《《《《《《《《《《
#
# ---
#
# ## 启动步骤：
#
# - 1. 手动运行第一步，等待至左下角弹出报错
#
# - 2. 选中第二步，然后左上角“代码执行程序”--第五项“运行当前单元格以及其后的所有单元格”
#
# - 3. 在最后一步，稍作等待之后，命令行会弹出: “Running on public URL: https://xxx.gradio.app” ， 点击它就可以进入部署好的页面.

# %% [markdown]
# # 0.杀掉colab进程，然后等待页面报错即可，结束后即可按顺序从 1 开始运行代码

# %%
#@title 1） kill colab 杀掉colab进程（或许有一些你在别的地方运行中的colab笔记，干掉它们。）


import os
os.kill(os.getpid(), 9)

# %% [markdown]
# # 1.【确保代码从最初始的状态运行，避免报错】

# %%
#@title 1）检查GPU状态

# !nvidia-smi
# Out:
# Thu Apr 13 06:59:05 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # 2.【把 云盘或者别的地方的 文件目录 加载 到 笔记的 运行目录中】

# %%
#@title 1）加载Google云端硬盘


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 3.【从原发布者github拉取最新版stable diffusion】

# %%
#@title  1）克隆git仓库
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git
# %cd stable-diffusion-webui
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 17850, done.
# remote: Total 17850 (delta 0), reused 0 (delta 0), pack-reused 17850
# Receiving objects: 100% (17850/17850), 28.25 MiB | 18.79 MiB/s, done.
# Resolving deltas: 100% (12507/12507), done.
# /content/stable-diffusion-webui

# %% [markdown]
# # 4.【为程序本体安装一些必需的组件】

# %%
#@title 1） 安装程序运行依赖

# !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Commit hash: 22bcc7be428c94e9408f589966c2040187245d81
# Installing gfpgan
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into /content/stable-diffusion-webui/repositories/taming-transformers...
# Cloning K-diffusion into /content/stable-diffusion-webui/repositories/k-diffusion...
# Cloning CodeFormer into /content/stable-diffusion-webui/repositories/CodeFormer...
# Cloning BLIP into /content/stable-diffusion-webui/repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Exiting because of --exit argument

# %% [markdown]
# # 5.【将 一些额外的文件 加载到 程序的目录中】

# %%
#@title 1）从云盘等地方加载额外文件【代码改写方法见代码注释】【可以按需更改代码，以便实现个性化一键部署】

#【0. 如果您临时性地不想加载某个文件，可以在代码行前使用"#"将其标为注释，便不会运行。(一次性注释多行代码的办法：选中--ctrl+/)】

#一些已经使用了的指令：

#【1. !cp  指令 是复制粘贴（复制目录下所有文件用-r，且目录末尾为*）】
#【2. !mkdir 指令 是创建目录（一口气创建多级文件夹用-p，同时在某个地方创建多个文件夹用：xxx/{name1,name2,...}/xxx）】
#【3. !rm  指令 是移除某个文件】
#【4. !curl 指令 是从指定的url链接获取内容（-L的意思是"跟踪重定向内容"，）】
#【5. %cd  指令 是变更代码生效的目录】

#【注意：如果您打算自己编写目录，请避免在为文件和文件夹命名的时候加入空格和中文字符等符号，如果路径的下划线断了，就表明那个地方的符号没有被指令识别，需要删去或者更改。】

#【以下是具体代码：】



# animefull-final-pruned文件夹 至 Stable-Diffusion文件夹
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/model-files/stableckpt/animefull-final-pruned/*  /content/stable-diffusion-webui/models/Stable-diffusion

# 删除final-pruned.vae.pt（如果您用该笔记产图，请在代码前边加上"#"以关闭；如果您用该笔记训练模型，请删掉"#"打开它。）
#!rm /content/stable-diffusion-webui/models/Stable-diffusion/final-pruned.vae.pt

# 创建hypernetworks, Stable-diffusion, preprocess文件夹
# !mkdir -p /content/stable-diffusion-webui/models/Stable-diffusion /content/stable-diffusion-webui/models/hypernetworks /content/stable-diffusion-webui/preprocess



#----------------------------------------------------配置自定义内容--代码--------------------------------------------------

# 我准备了两个文件夹，一个embeddings，一个hypernetworks，各位可以把自己已经有的模型装到云端，这两条指令会帮你把它们送到程序内
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/model-files/embeddings/* /content/stable-diffusion-webui/embeddings

# 我准备了两个文件夹，一个embeddings，一个hypernetworks，各位可以把自己已经有的模型装到云端，这两条指令会帮你把它们送到程序内
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/model-files/hypernetworks/* /content/stable-diffusion-webui/models/hypernetworks

# 一键安装自己准备的scripts（放至云端文件夹内即可）
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/scripts/* /content/stable-diffusion-webui/scripts

# modules文件夹下 所有内容 至 hypernetworks文件夹下
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/model-files/stableckpt/modules/modules/* /content/stable-diffusion-webui/models/hypernetworks

# extensions文件夹下 所有内容 至 extensions文件夹下
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/extensions/* /content/stable-diffusion-webui/extensions

# javascript文件夹下 所有内容 至 javascript文件夹下
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/javascript/* /content/stable-diffusion-webui/javascript

# models文件夹下 所有内容 至 models文件夹下
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/models/* /content/stable-diffusion-webui/models

# modules文件夹下 所有内容 至 modules文件夹下
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/modules/* /content/stable-diffusion-webui/modules

# textual_inversion_templates文件夹下 所有内容 至 textual_inversion_templates文件夹下
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/textual_inversion_templates/* /content/stable-diffusion-webui/textual_inversion_templates

# stable-diffusion-webui文件夹下 所有内容 至 stable-diffusion-webui文件夹下（程序根目录下）  (包括但不限于 webUI配置文件)
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/stable-diffusion-webui/* /content/stable-diffusion-webui

# 备注：因为有上面那一条了，所以这一条弃置不用了。
# config.json（这是配置文件，先暂时用我的，如果你想用自己的，就用同名文件替换掉云端的那个） 至 config.json（根目录下）
#!cp /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/config.json /content/stable-diffusion-webui/config.json

# localizations文件夹下 所有内容 至 localizations文件夹下  (包括但不限于 本地化汉化文件)
# !cp -r /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/localizations/* /content/stable-diffusion-webui/localizations

# 备注：因为有上面那一条了，所以这一条弃置不用了。
# Chinese-English.json(汉化文件) 至 Chinese-English.json（localizations目录下）
#!cp /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/Chinese-English.json /content/stable-diffusion-webui/localizations/Chinese-English.json

#----------------------------------------------------配置自定义内容--代码--------------------------------------------------



# 移除 v1-inference.yaml
# !rm /content/stable-diffusion-webui/configs/v1-inference.yaml

# config.yaml 至 v1-inference.yaml
# !cp /content/drive/MyDrive/stable-diffusion-preparations/model-files/stableckpt/animefull-final-pruned/config.yaml /content/stable-diffusion-webui/configs/v1-inference.yaml




#以下是摘抄的指令，仅保留了"安装 训练用7G模型 "指令。(注：加载7G模型的时候有概率会崩溃，如果要用，可以参考一下下方的一些注解，实在不行就还是用4g模型罢，或者要不要考虑加钱换个好的？（笑）)



# %cd /content/stable-diffusion-webui/models/Stable-diffusion/



# Install custom embeddings (modified, optional)（自定义化，可选）（这是一些自定义embeddings库存，如果想玩点花的，可以把注释取消掉让这个命令运行，但是想从中找到你自己上传的模型可能会比较费劲，所以默认关闭）
# !curl -L https://cloudflare-ipfs.com/ipfs/bafybeie3hdjchxs5tz4n75bos53nhcklslguxchdurc2ynrzcfv2kwyklu/embeddings.tar | tar x -C /content/stable-diffusion-webui/embeddings


# 7G animefull-final-latest (may not work on free plan)（免费colab提供的内存不足以加载这个模型【会在最后一步爆内存并显示^C】，但是我们并非束手无策，解决办法见第七步注释）（为了程序顺利运行，我把它暂存到程序外边，请手动拖入models/stable-diffusion 文件夹里！）

# ---------------------------------

# !mkdir -p /content/7G_model_is_here/if_you_dont_train_you_can_ignore_this
# !curl -Lo /content/7G_model_is_here/final-pruned.ckpt https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/animefull-latest.ckpt
# !curl -Lo /content/stable-diffusion-webui/config.yaml https://cloudflare-ipfs.com/ipfs/bafybeiav3j7npiuewbel3mi32l3sidgkw54kuleosbhxmdvddbnvtfi7yu/config.yaml

# ---------------------------------






# （下边是dalao的一些源代码，但是这些已经装了，所以弃置不用了。）

# 4G animefull-final-pruned
#!curl -Lo model.ckpt https://cloudflare-ipfs.com/ipfs/bafybeicpamreyp2bsocyk3hpxr7ixb2g2rnrequub3j2ahrkdxbvfbvjc4/model.ckpt
#!curl -Lo /content/stable-diffusion-webui/config.yaml https://cloudflare-ipfs.com/ipfs/bafybeiav3j7npiuewbel3mi32l3sidgkw54kuleosbhxmdvddbnvtfi7yu/config.yaml

# Install VAE Weights (optional)
#!curl -Lo model.vae.pt https://cloudflare-ipfs.com/ipfs/bafybeiccldswdd3wvg57jhclcq53lvsc6gizasiblwayvhlv6eq4wow7wu/animevae.pt 

# Install hypernetwork （optional)
#!curl -L https://cloudflare-ipfs.com/ipfs/bafybeiduanx2b3mcvxlwr66igcwnpfmk3nc3qgxlpwh6oq6m6pxii3f77e/_modules.tar | tar x -C /content/stable-diffusion-webui/models/hypernetworks
# Out:
# /content/stable-diffusion-webui/models/Stable-diffusion

# %% [markdown]
# # 6.【xformers部署（可选）（默认关闭）】
#
# ### 注：
#
# 【如果您确实需要它，请在 启动程序之前 增加 相应的启动参数"--xformers"】
#
# 【您也可以考虑 直接不运行这部分代码 来增加部署速度（默认关闭）】

# %%
#@title 1）安装并加载xofrmers ： 降低显卡压力，略微减少图片质量，取而代之的是可以跑更大分辨率的图



#在不删除代码的情况下，使代码不运行：使用"长注释"：（在首尾添加【'''】或者【"""】。）
#代码抄的dalao的，本人也没实际用过，不敢保证可用性，不过有值得一试的价值，但是需要等待一段时间。

# %cd /content/stable-diffusion-webui/



# pip install pyre-extensions==0.0.23

# pip install numpy



# git clone https://github.com/facebookresearch/xformers/

# cd xformers

# git submodule update --init --recursive

# pip install --verbose --no-deps -e .
# Out:
# /content/stable-diffusion-webui

# %% [markdown]
# # 7. 【向gradio申请一个可以使用webUI的网页链接】部署模型到gradio网站中
#
# ---
#
# 运行该命令，稍作等待之后，命令行会弹出:
#
# Running on public URL: https://xxx.gradio.app
#
# 点击它就可以进入部署好的页面.
#
# 【如有需要，请修改代码，修改方式见代码注释】
#
# 【默认账号密码：2333，6666（但这并不安全，因为任何知道你网址和账号密码的人 都可以在任何地方登录到你刚刚申请的网站上，并和你共用 UI 和 生成进度 和 结果，为避免一些网络爬虫的干扰，建议您将密码改得复杂些。）】
#
# ---
#
# ##【以下是一些使用小技巧：】
# 1. 左侧菜单有“文件”菜单栏，在那个地方您可以看见保存在笔记上的所有文件（注意！当笔记停止运行后，这里的所有文件都将被清空。）
#
# 2. 在“文件”菜单栏内可以可以操作文件和文件夹，以及复制它的目录 等 操作。（对其右键即可选择操作）（笔记内的“drive”网盘目录文件夹也一样可以复制其目录）（“‘复制文件所在目录’会很常用，因为webUI需要你提供各种各样的目录”）
#
# 3. 左侧“文件”菜单栏的图片，可以通过鼠标双击来直接在网页中显示预览，当然也可以通过右键下载查看。
#
# 4. 将各种目录定在云存储中，这样你的操作所产生的数据就可以实时地被保存下来，而不是因为各种意外而被colab清除掉（但是要留心你的Google drive剩余容量，15个g并不是很宽裕。）
# 5. 如果您打算关闭这个笔记，请在左上角“代码执行程序”--“断开连接并删除运行时”来手动关闭，而不是直接关闭网页。否则您的笔记就会在你离开后继续运行，直到被colab叫停并没收当日免费gpu算力。（程序是否在运行状态？可以查看右上角“修改”左侧的显示栏的状态，如果显示了占用情况，或是“忙碌中”，那就意味着你的笔记现在正在使用colab提供的资源。）
#
# 6. 还记得文章开头我提供的工具网站吗？它们会帮上忙的。
#
# ---
#
# ### 祝你用的开心！
#
#
# ---
#
# 临时备注：最近的问题（使用方面）：colab免费提供的资源不足以加载7g模型，会导致云端爆内存，命令行出现^C而崩溃。
#
# 目前的办法：先把7G模型拖出SD根目录（我已经通过代码实现了，去根目录里的“7G_model_is_here”文件夹里找），等程序加载完，已经弹出链接了之后，再把7G模型文件拖回来，最后在UI内左上角刷新并选择model.ckpt，等他加载，有很大概率加载成功（在后台可以看见执行情况，看到 “weights loaded”就表明模型加载成功了。然后您就可以开始训练模型了！）
#
# ---
#
# 备注2：请确保7G模型的大小达到7.17G再拖入models，否则加载会报错（解决方法：删掉文件，然后再运行一遍第五步，成功率取决于colab与下载源之间的网络稳定性）
#
# ---

# %%
#@title 【在此可以添加命令行参数】【详细解释见代码内注释】
#  --share          - 创建一个在线的 gradio.app 链接（其实您在自己电脑的本地运行的程序上也可以添加本参数，不过对于运行程序的本机而言，127.0.0.1:7860也能达到一样的效果。）
#  --gradio-debug       - 打印输出到控制台
#  --gradio-auth 2333:6666  - 创建用户，账号为2333，密码为6666，可以自行修改，用作登陆账号密码
#  --deepdanbooru       - 开启deepdanbooru功能，在"图生图"处增加"反向分析输入图片tags"的功能（需要另行安装，这会占用一些启动时间）
#  --xformers         - 开启xformers优化，开启前请确保您已顺利运行了xformers安装代码（需要一定的等待时间）
#  --（其他）         -有些scripts需要你添加他们自带的启动参数，也在这加



# 将命令生效目录改回到程序源目录下，然后启动目录下的 lauch.py 文件（附带参数项）

# %cd /content/stable-diffusion-webui/

# !COMMANDLINE_ARGS=" --share --gradio-debug --gradio-auth 2333:6666 --disable-safe-unpickle " REQS_FILE="requirements.txt" python launch.py





#》》》》》》》》》》》》以下是复制自dalao的修改文本，但是暂不加入运行程序中《《《《《《《《《《《《



#----------------------------Start
#!sed -i -e "125 c \ \ \ \ sd = pl_sd" /content/stable-diffusion-webui/modules/sd_models.py      #if use 7G version, turn this on.
#隐藏输出项，防止页面卡顿和内存溢出。
#import os, sys
#class HiddenPrints:
#    def __enter__(self):
#        self._original_stdout = sys.stdout
#        sys.stdout = open(os.devnull, 'w')

#    def __exit__(self, exc_type, exc_val, exc_tb):
#        sys.stdout.close()
#        sys.stdout = self._original_stdout
#with HiddenPrints():
#        !python webui.py --autolaunch --precision autocast --config config.yaml & bore local 7860 --to bore.pub -p xxxxx
# Out:
# /content/stable-diffusion-webui
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Commit hash: 22bcc7be428c94e9408f589966c2040187245d81
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --gradio-debug --gradio-auth 2333:6666 --disable-safe-unpickle
# 2023-04-10 15:13:57.678313: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-10 15:14:00.051106: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# No module 'xformers'. Proceeding without it.
# ...

# %% [markdown]
# # 8.一些手动运行的代码【调试工具 或者 文件保存代码】
# ### 注：
#
# #### 1.需要先停止第七步的程序（点击代码行左上角的圆，即可开始运行/停止运行程序）
#
# #### 2.需要colab还能被使用（超出了使用时间限制而被强制停止colab的话，不仅这段代码无法被运行，待保存的配置文件也会被清除掉，敬请注意）

# %%
#@title 1）【将 配置文件等文件 保存回云盘里】

#config.json 保存到云盘指定路径，下次运行笔记的时候会自动加载回来。
# !cp /content/stable-diffusion-webui/config.json /content/drive/MyDrive/stable-diffusion-preparations/extra-locolization-files-plugins-etc/stable-diffusion-webui/config.json

#这个位置留给其他需要保存的 配置文件 等 用户数据，复制文件用 !cp , 复制文件目录用 !cp -r ，使用格式参考第五步。
#!cp -r /content/stable-diffusion-webui/(ヮ´ )σ∀´) ﾟ∀ﾟ)σ/*  /content/drive/MyDrive/stable-diffusion-preparations/(ヮ´ )σ∀´) ﾟ∀ﾟ)σ/

# %%
#@title 手动加载VAE模型权重文件

# animevae.pt 至 final-pruned.vae.pt
#!cp /content/drive/MyDrive/stable-diffusion-preparations/model-files/stableckpt/animevae.pt /content/stable-diffusion-webui/models/Stable-diffusion/final-pruned.vae.pt

# %%
#@title 手动卸载VAE模型权重文件

# 删除final-pruned.vae.pt
#!rm /content/stable-diffusion-webui/models/Stable-diffusion/final-pruned.vae.pt

# %% [markdown]
# # 9.附录：
#
# ---
#
# ###[如有遗漏，欢迎各位私信我补充！ (ゝ∀･)](https://space.bilibili.com/12171834)
#
# ### 另：再次感谢以下dalao的辛勤付出！
#
# ---
#
# ---
#
# ## 1.一些 有用的或者值得参考的视频 或 法师交流平台：
#
# ---
#
# ---
#
# ### （1）.各种聊天室 或 讨论组 或 交流群：
#
# 【QQ频道】【频道号】【秋叶的甜品店】3764f45toc
#
# 【QQ频道】【频道号】【NOVEL AI B站频道】i7jw4rb2r2
#
# 【QQ频道】【频道号】【NOVEL AI 贴吧频道】u31uiz208r
#
# 【discord】【与外国友人共同探讨咒术的聊天频道】【内置翻译机器人】【[加入链接](https://discord.com/invite/n9pbyYjG4y)】
#
# 【QQ群】【AI绘画交流群】703710185
#
# 【QQ群】【AI绘画，tags分享，部署（没有机器人！！）】222066698
#
# ---
#
# ### （2）.各种dalao的账号主页 或 个人博客 或 个人网站（友情链接）：
#
# 【Novel Ai Tag novel ai 魔导书 网站作者】https://space.bilibili.com/6537379
#
# 【Stable-Diffusion webUI原作者的博客】【综合性资源及教程站】https://rentry.org/voldy
#
# 【秋葉aaaki的个人空间-哔哩哔哩】 https://b23.tv/Zyecpq5
#
# 【元素法典制作委员会的个人空间-哔哩哔哩】 https://b23.tv/danKntJ
#
# 【novel ai 自助资源站】https://g.h5gd.com/p/yuvwitqh
#
# 【dalao整理的 关于ai绘图的资料合集】【github仓库】https://github.com/hua1995116/awesome-ai-painting
#
# 【ai绘图相关资源 资源站】【全英文】https://pharmapsychotic.com/tools.html
#
# 【dalao自建 novel ai 工具站】【秋枼的网站】https://novelai.dev/
#
# ---
#
# ### （3）.各种论坛：
#
# 【AI艺术】http://bbs.cgkit.cn/forum.php
#
# 【novel ai 魔导学院】https://noveltags.com/
#
# 【AIfun】https://aitags.fun/
#
# ---
#
# ### （4）.各种值得学习和参考的教学视频或帖子（更多请见我b站账号收藏夹，那里最先更新）：
#
# 【官方wiki，可以认为是对stable diffusion用法的最权威解释】https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki
#
# 【tag的进阶组合法 贴】http://bbs.cgkit.cn/forum.php?mod=viewthread&tid=32&fromuid=53
#
# 【NovelAI云端部署系列教程-安装xformers加速你的图片生成吧！-哔哩哔哩】 https://b23.tv/1fwx8AO
#
# 【【AI绘画】保姆式教程！让你的AI学会其他画师的画风与人物-哔哩哔哩】 https://b23.tv/RNTL3Co
#
# 【novelAI炼金师必备！打造属于自己的魔法书，用excel快速存储与生成novelai tag（第二版）-哔哩哔哩】 https://b23.tv/9QvwEqc
#
# 【NovelAI Tag查询工具-哔哩哔哩】 https://b23.tv/O7EQkgV
#
# 【【NovelAI】没有好显卡怎么办，手把手教你白嫖google colab 使用NovelAI-哔哩哔哩】 https://b23.tv/Lq7LbKp
#
# 【【NovelAI】角色与画风tag训练十问，常见问题整理与解答-哔哩哔哩】 https://b23.tv/jGduiAZ
#
# 【【NovelAI】利用Colab来在线训练自己的tag，以Hiten画风tag为例-哔哩哔哩】 https://b23.tv/U9UDPaP
#
# 【【开源调研+汉化】AI绘画全参数讲解-001翻译与txt2img文本到图像(含STABLE DIFFUSION WEBUI汉化+全参数不敷衍讲解)-哔哩哔哩】 https://b23.tv/5SLOtPf
#
# 【教你如何让ai画手！-哔哩哔哩】 https://b23.tv/joMbwH5
#
# 【【NovelAI大魔导书】教科书级的壁纸展示-哔哩哔哩】 https://b23.tv/BmKu3fp
#
# 【【中级AI作画】颠覆你想象—中级AI作画魔法课堂。【novelai】-哔哩哔哩】 https://b23.tv/QZpRW9x
#
# 【【Novelai】超简单！手机轻松跑图！-哔哩哔哩】 https://b23.tv/VSfHMSI
#
# 【【AI绘画】手把手教学让AI学会画你的老婆!强大的hypernetwork模型-哔哩哔哩】 https://b23.tv/jRmH9ys
#
# 【【二次元Ai】NovelAi 本地版详细安装教程！二次元必备！-哔哩哔哩】 https://b23.tv/hmOmboK
#
# 【【AI绘图】NovelAI 魔法咒语tag完全解析 从入门到精通的效果优化全攻略-哔哩哔哩】 https://b23.tv/eT6AXao
#
# 【【AI绘画】Novel 调优与风格-创作者如何利用Novel AI & 版权时代下的穷途末路？-哔哩哔哩】 https://b23.tv/W59U0Bv
#
# 【【AI绘画】再次进化！novelai真官网版本解压即用 无需下载！这次1分钟内不用学也能会用-哔哩哔哩】 https://b23.tv/YiaFyLO
#
# 【【AI绘画】NovelAI终极傻瓜教程 无需任何环境 colab完全线上部署 A卡福音 （可可罗老师讲授）-哔哩哔哩】 https://b23.tv/aVgzc8o
#
# 【【AI绘画】AI不认识人物怎么办！强大的Textual Inversion【NovelAI】-哔哩哔哩】 https://b23.tv/etdm4VU
#
# 【novelAI炼金师必备！打造属于自己的魔法书，用excel快速存储与生成novelai tag（第二版）-哔哩哔哩】 https://b23.tv/VFuhhjS
#
# ---
#
# ---
#
# ## 2.一些有用的工具网站 或 资源发布站 或研究成果发布贴：
#
# ---
#
# ---
#
# ### （1）.各种关键词（tag与prompt）的分享与研究：
#
# 【NovelAI可用tag关键词收集（一 · 姿势，构图）】【[原文地址](https://www.bilibili.com/read/cv19007299)】
#
# 【NovelAI可用tag关键词收集（二 · 头发，表情）】【[原文地址](https://www.bilibili.com/read/cv19008409)】
#
# 【NovelAI可用tag关键词收集（三 · 身体，服装）】【[原文地址](https://www.bilibili.com/read/cv19010392)】
#
# 【NovelAI可用tag关键词收集（四 · 背景，其他）】【[原文地址](https://www.bilibili.com/read/cv19011382)】
#
# 【关于tags的使用：booru系tag效果更好】【[原帖地址](https://tieba.baidu.com/p/8085717971?cid=0&pid=145803217648#145803217648)】
#
# 【常用tag与瑟瑟tag：1】【[下载地址](https://pan.baidu.com/s/1-29zRB0Wd7VK0h3wiM1utg?pwd=ia8y)；提取码：ia8y；解压密码：0714。】【[发布地址](https://www.bilibili.com/read/cv19061010)】
#
# 【常用tag与瑟瑟tag：2】【建议前往发布页】【[蓝奏云（密码0714）](https://wwd.lanzoue.com/iE59r0farb9i)】【[百度云（提取码：imd0）](https://pan.baidu.com/s/1PMfAB1blBvlbqHKROg-6lA?pwd=imd0)】【[谷歌云盘](https://docs.google.com/spreadsheets/d/19C7KI6VEixHLQKQxS6Iqt7YHXlGWku0iVxI1tu-03uo/edit?usp=sharing)】【[教程与资源发布地址](https://www.bilibili.com/read/cv19556763)】
#
# 【4万tags】【建议配合发布视频使用】【[下载链接](https://pan.baidu.com/s/1HxoIipgiISnhtwouJ3EnJQ)；提取码：ljff；解压密码：1。】【[原视频链接](https://www.bilibili.com/video/BV1m84y1B7Ny/?vd_source=6a273e904b0a3bcc92b117a36f66ca70)】
#
# ---
#
# ### （2）.各种辅助工具 或 工具网站：
#
# 【ai生成高清图片】https://bigjpg.com/
#
# 【ai生成高清图片】【waifu2x】http://waifu2x.udp.jp/
#
# 【removebg 在线给图抠掉背景】https://www.remove.bg/zh/upload
#
# 【在线photoshop】https://www.photopea.com/
#
# 【birme 图片批量粗处理】【适合用于深度学习前的图片1：1预处理】https://www.birme.net/
#
# 【图片无损放大本地软件】【Real-ESRGAN-ncnn-vulkan】【[windows](https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.5.0/realesrgan-ncnn-vulkan-20220424-windows.zip)】【[linux](https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.5.0/realesrgan-ncnn-vulkan-20220424-ubuntu.zip)】【[macos](https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.5.0/realesrgan-ncnn-vulkan-20220424-macos.zip)】【[源仓库地址](https://github.com/xinntao/Real-ESRGAN-ncnn-vulkan)】
#
# 【stable diffusion search engine】【关键tag查询ai绘图成品】https://lexica.art/
#
# 【dalao自制ai绘图查询工具】【手机app】https://chaojiyun.lanzouv.com/b0d4rdg5e 【[发布地址在这里](https://www.bilibili.com/video/BV1JK411Q7MS/?vd_source=6a273e904b0a3bcc92b117a36f66ca70)】
#
# 【大佬的AI提词器应用】https://wwu.lanzouw.com/i5Ltr0dyczid
# 【[该程序发布地址在此](https://www.bilibili.com/read/cv19028791)】【解压密码 123456】【建议去发布地址寻找最新版】
#
# 【词条生成器 by wolfchen】【也可作为魔导书使用】https://wolfchen.top/tag/ 【[github仓库地址](https://github.com/WolfChen1996/NovelAI-tag-generator)】
#
# 【魔咒百科词典】https://aitag.top/
#
# 【dalao自建deepdanbooru】http://dev.kanotype.net:8003/deepdanbooru/
#
# 【dalao自建novel ai 法术解析】https://spell.novelai.dev/
#
# 【Novel AI 魔导书】【可生成词条】https://thereisnospon.github.io/NovelAiTag/
#
# 【魔导绪论】【tag生成器】https://magic-tag.netlify.app/#/
#
# 【qq机器人插件（借助koishi）】【需要novel ai有效付费账号】https://bot.novelai.dev
#
# 【基于训练模型作为权重的p站涩图智能识图爬虫机器人】【[gayhub仓库](https://github.com/7eu7d7/pixiv_AI_crawler)】【[colab笔记页面](https://colab.research.google.com/drive/1jwZehdQ4V5rR2M8n1wAJ7P8QHstMAjOl?usp=sharing)】
#
# ---
#
# ### （3）.各种成品资源（包括但不限于tag合集列表 以及 优秀tag组合 以及 训练模型分享）：
#
# 【法术合集】【已分类】https://docs.google.com/spreadsheets/d/e/2PACX-1vRa2HjzocajlsPLH1e5QsJumnEShfooDdeHqcAuxjPKBIVVTHbOYWASAQyfmrQhUtoZAKPri2s_tGxx/pubhtml#
#
# 【《 元 素 法 典 》本体】https://docs.qq.com/doc/DWHl3am5Zb05QbGVs
#
# 【novel ai资源整合文档】https://www.kdocs.cn/l/cvg8ccOGj5sq
#
# 【语雀】【个人tag记录笔记】https://www.yuque.com/longyuye/lmgcwy/nhnwrz#yxbuh
#
# 【文档】【novel ai 信息并联计划】https://docs.qq.com/sheet/DRHJNb0NVZHBxVEVQ?tab=BB08J2
#
# 【novel ai关键词记录效果与研究】https://docs.qq.com/doc/DQ05STUdCcnFXWWpH?friendUin=8mcawZcr%252BTV9eAkH6408kw%253D%253D&dver=
#
# 【秋葉自己的频道 的 自制咒术收录文档】https://docs.qq.com/doc/DR0d3aEdzSmxORE5w
#
# 【dalao自建 novel ai 咒语分享网站】【不建议科学上网】http://tag.cerfai.com/#/
#
# 【dalao自建 danbooru标签、embeddings模型 超市】【已分类】https://tags.novelai.dev
#
# 【来自官方提供的一些模型文件】https://github.com/runwayml/stable-diffusion
#
# 【某个dalao自己存的模型文件】https://gitlab.com/16777216c/stable-diffusion-embeddings/-/tree/main/embeddings
#
# 【一些免费的模型文件】https://rentry.org/sdmodels
#
# ---
#
# ---
#
# ## 3.或许没什么用，或者已经失去了原本的意义，但确实是与ai绘画相关的网站：
#
# ---
#
# ---
#
# ### （1）.各大（大都付费）提供ai绘图服务的企业势网站：
#
# 【Novel ai官网】【默哀10^-5秒】https://novelai.net/
#
# 【】
#
# 【】
#
# ---
#
# ### （2）.进行相关研究的企业势网站：
#
# 【腾讯ARC Lab】https://arc.tencent.com/zh/ai-demos/imgRestore
#
# 【】
#
# 【】
